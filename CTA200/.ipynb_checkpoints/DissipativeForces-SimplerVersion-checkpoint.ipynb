# %%
import rebound as rb
from matplotlib import pyplot as plt
import celmech as cm
import numpy as np
import sympy as sp

# %%
sim=rb.Simulation()
sim.add(m=1)
sim.add(m=1e-4,P=1)
sim.add(m=1e-4,P=1.5)
pvars = cm.Poincare.from_Simulation(sim)
pham = cm.PoincareHamiltonian(pvars)

# %%
pham.add_MMR_terms(3,1)

# %%
A = np.eye(pham.N_dof,dtype = int)
A[0,:4] = [-2,3,1,0]
A[1,:4] = [-2,3,0,1]
A[2,:4] = [1,-1,0,0]
A[3,:4] = [-2,3,0,0]
angvars=sp.symbols("theta1,theta2,psi,l,phi1,phi2",real=True)
actions=sp.symbols("p1,p2,Psi,L,Phi1,Phi2",positive=True)
_,_,Psi,L,_,_=actions
ct1 = cm.CanonicalTransformation.from_poincare_angles_matrix(pvars,A,new_qp_pairs=list(zip(angvars,actions)))

# %% [markdown]
# 'ham1' will be the Hamiltonian in the resonant variables you're used to

# %%
ham1=ct1.old_to_new_hamiltonian(pham,do_reduction=True)
ham1.H
# Out:
#                                                                     ____
#   √2⋅C_{(3,-2,-1,0,0,0)}_{1,2})__{(0,0,0,0),(0,0)}(\alpha⋅G⋅m₁⋅m₂⋅╲╱ p₁ ⋅cos(θ
# - ────────────────────────────────────────────────────────────────────────────
#                               _______________
#                             ╲╱ \Lambda_{1,0} ⋅a_{2,0}
#
#                                                                        ____
# ₁)   √2⋅C_{(3,-2,0,-1,0,0)}_{1,2})__{(0,0,0,0),(0,0)}(\alpha⋅G⋅m₁⋅m₂⋅╲╱ p₂ ⋅co
# ── - ─────────────────────────────────────────────────────────────────────────
#                                  _______________
#                                ╲╱ \Lambda_{2,0} ⋅a_{2,0}
#
#                   2   2   3                    2   2   3
# s(θ₂)            G ⋅M₁ ⋅μ₁                    G ⋅M₂ ⋅μ₂
# ───── - ─────────────────────────── - ──────────────────────────
#                                   2                            2
#         2⋅(-2⋅L + Ψ - 2⋅p₁ - 2⋅p₂)    2⋅(3⋅L - Ψ + 3⋅p₁ + 3⋅p₂)

# %% [markdown]
# 'ham2' transforms from polar $(\theta_i,p_i)$ variables to cartesian $(y_i,x_i)$ variables. These are usually more convenient for numerical integration and root-finding

# %%
ct2 = cm.CanonicalTransformation.polar_to_cartesian(ham1.full_qp_vars,indices=[0,1])

ham2=ct2.old_to_new_hamiltonian(ham1)
ham2.H
# Out:
#
#   C_{(3,-2,-1,0,0,0)}_{1,2})__{(0,0,0,0),(0,0)}(\alpha⋅G⋅m₁⋅m₂⋅x₁   C_{(3,-2,0
# - ─────────────────────────────────────────────────────────────── - ──────────
#                        _______________
#                      ╲╱ \Lambda_{1,0} ⋅a_{2,0}
#
#
# ,-1,0,0)}_{1,2})__{(0,0,0,0),(0,0)}(\alpha⋅G⋅m₁⋅m₂⋅x₂
# ───────────────────────────────────────────────────── - ──────────────────────
#            _______________                                 2                 2
#          ╲╱ \Lambda_{2,0} ⋅a_{2,0}                      8⋅L  - 8⋅L⋅Ψ + 8⋅L⋅x₁
#
#                                                                             2
#                                                                            G ⋅
# ──────────────────────────────────────────────────────────────────────────────
#          2         2         2      2         2         2         2         2
#  + 8⋅L⋅x₂  + 8⋅L⋅y₁  + 8⋅L⋅y₂  + 2⋅Ψ  - 4⋅Ψ⋅x₁  - 4⋅Ψ⋅x₂  - 4⋅Ψ⋅y₁  - 4⋅Ψ⋅y₂
#
#   2   3
# M₁ ⋅μ₁
# ──────────────────────────────────────────────────────────────────────────────
#       4       2   2       2   2       2   2       4       2   2       2   2
# + 2⋅x₁  + 4⋅x₁ ⋅x₂  + 4⋅x₁ ⋅y₁  + 4⋅x₁ ⋅y₂  + 2⋅x₂  + 4⋅x₂ ⋅y₁  + 4⋅x₂ ⋅y₂  +
#
#
#
# ───────────────────────── - ──────────────────────────────────────────────────
#     4       2   2       4       2                   2          2          2
# 2⋅y₁  + 4⋅y₁ ⋅y₂  + 2⋅y₂    36⋅L  - 24⋅L⋅Ψ + 36⋅L⋅x₁  + 36⋅L⋅x₂  + 36⋅L⋅y₁  +
#
#                                                          2   2   3
#                                                       2⋅G ⋅M₂ ⋅μ₂
# ──────────────────────────────────────────────────────────────────────────────
#        2      2          2          2          2          2       4        2
# 36⋅L⋅y₂  + 4⋅Ψ  - 12⋅Ψ⋅x₁  - 12⋅Ψ⋅x₂  - 12⋅Ψ⋅y₁  - 12⋅Ψ⋅y₂  + 9⋅x₁  + 18⋅x₁ ⋅x
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#  2        2   2        2   2       4        2   2        2   2       4
# ₂  + 18⋅x₁ ⋅y₁  + 18⋅x₁ ⋅y₂  + 9⋅x₂  + 18⋅x₂ ⋅y₁  + 18⋅x₂ ⋅y₂  + 9⋅y₁  + 18⋅y₁
#
#
#
# ─────────────
# 2   2       4
#  ⋅y₂  + 9⋅y₂

# %% [markdown]
# A composite transformation representing all the transformations so far

# %%
ct_all = cm.CanonicalTransformation.composite([ct1,ct2])

# %%
oldvars = ct_all.old_qp_vars
_,eta1,_,_,eta2,_,L1,kappa1,_,L2,kappa2,_= oldvars
newvars = ct_all.new_qp_vars
y1,y2,_,_,_,_,x1,x2,Psi,L,_,_ = newvars

# %% [markdown]
# Conserved quantities after transformation:

# %%
L,ct_all.new_to_old(L)
# Out:
# ⎛               2     2     2     2⎞
# ⎜             η₁    η₂    κ₁    κ₂ ⎟
# ⎜L, Λ₁ + Λ₂ - ─── - ─── - ─── - ───⎟
# ⎝              2     2     2     2 ⎠

# %%
Psi,ct_all.new_to_old(Psi)
# Out:
# (Ψ, 3⋅Λ₁ + 2⋅Λ₂)

# %% [markdown]
# ## dissipation
# The effect of dissipation, written in terms of the original variables

# %%
tau_a1,tau_a2,tau_e1,tau_e2 = sp.symbols("tau_a1,tau_a2,tau_e1,tau_e2")
disflow = sp.Matrix(np.zeros(pham.N_dim))
for hk,tau in zip([(eta1,kappa1),(eta2,kappa2)],(tau_e1,tau_e2)):
    h,k = hk
    disflow[oldvars.index(h)] = -h/tau
    disflow[oldvars.index(k)] = -k/tau
disflow[oldvars.index(L1)] = -L1/tau_a1/sp.S(2)
disflow[oldvars.index(L2)] = -L2/tau_a2/sp.S(2)
disflow
# Out:
# ⎡  0  ⎤
# ⎢     ⎥
# ⎢-η₁  ⎥
# ⎢──── ⎥
# ⎢τₑ₁  ⎥
# ⎢     ⎥
# ⎢  0  ⎥
# ⎢     ⎥
# ⎢  0  ⎥
# ⎢     ⎥
# ⎢-η₂  ⎥
# ⎢──── ⎥
# ⎢τₑ₂  ⎥
# ⎢     ⎥
# ⎢  0  ⎥
# ⎢     ⎥
# ⎢ -Λ₁ ⎥
# ⎢─────⎥
# ⎢2⋅τₐ₁⎥
# ⎢     ⎥
# ⎢-κ₁  ⎥
# ⎢──── ⎥
# ⎢τₑ₁  ⎥
# ⎢     ⎥
# ⎢  0  ⎥
# ⎢     ⎥
# ⎢ -Λ₂ ⎥
# ⎢─────⎥
# ⎢2⋅τₐ₂⎥
# ⎢     ⎥
# ⎢-κ₂  ⎥
# ⎢──── ⎥
# ⎢τₑ₂  ⎥
# ⎢     ⎥
# ⎣  0  ⎦

# %% [markdown]
# Define $(D, L_2)$ new variables s.t.
# $$
# \begin{pmatrix}
# L\\
# \Psi
# \end{pmatrix}
# =
# \begin{pmatrix}
# -1 & 1+\rho\\
# 0 & j\rho+(j-1)
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# D\\
# L_2
# \end{pmatrix}
# $$
# where $\rho = \left(\frac{\Lambda_1}{\Lambda_2}\right)_\mathrm{res} \approx \frac{m_1}{m_2}\left(\frac{j-1}{j}\right)^{1/3}$.
#
# In terms of old variables,
# $$
# L = \Lambda_{1} + \Lambda_{2} - \frac{\eta_{1}^{2}}{2} - \frac{\eta_{2}^{2}}{2} - \frac{\kappa_{1}^{2}}{2} - \frac{\kappa_{2}^{2}}{2} = (1 + \rho)L_2 - D\\
# \Psi = j \Lambda_{1} + (j-1) \Lambda_{2} = (j\rho+(j-1))L_2~.
# $$
# In other words, $L_2$ represents the value of $\Lambda_2$ when the planets' instantaneous period ratio is at the exact resonant value and $D$ is the value of $(p_1+p_2)$ when $\Lambda_2 = L_2$.
#
# The planets' period ratio can be expressed in terms of
# $$
# \Delta = \frac{j-1}{j}\frac{P_2}{P_1} - 1 \approx 3\left(\frac{\Lambda_2 - L_2}{L_2} - \frac{\Lambda_1 - \rho L_2}{\rho L_2}\right) = 3\frac{\delta\Lambda_2}{L_2}\left(1+\frac{j-1}{j\rho}\right)
# $$
# where $\delta\Lambda_2 = \Lambda_2 - L_2$
#
# Therefore, we can write
# $$
# D = p_1+p_2+(1+\rho)L_2-\Lambda_1 - \Lambda_2
# $$
# Or
# $$
# \begin{eqnarray}
# D &=& p_1+p_2 - \frac{1}{j}\delta\Lambda_2\\
#   &=& p_1+p_2 - \frac{1}{3}\left(\frac{\rho L_2}{j\rho+j-1}\right)\Delta
# \end{eqnarray}
# $$
#
# The dissipative evolution of $D$ is therefore
# $$
# \begin{eqnarray}
# \dot{D}\big|_\mathrm{dis} &=&-\frac{p_1}{\tau_{e1}}-\frac{p_2}{\tau_{e2}}- \frac{1}{3}\left(\frac{\rho L_2}{j\rho+j-1}\right)\dot{\Delta}\big|_\mathrm{dis}\\
# &=&
# -\frac{p_1}{\tau_{e1}}-\frac{p_2}{\tau_{e2}}+\frac{1}{2}\left(\frac{\rho L_2}{j\rho+j-1}\right)\frac{1}{\tau_\alpha}
# \end{eqnarray}
# $$
# where $\tau_\alpha^{-1} = \tau_{a,1}^{-1}- \tau_{a,2}^{-1}$

# %%
D,L2res,rho = sp.symbols("D,L2,rho")
rho_val = pham.qp[L1]/pham.qp[L2]
mtrx = sp.Matrix([[-1,1+rho],[0,3*rho + 2]]) #* sp.Matrix([D,L2res])
D_exprn,L2res_exprn = mtrx.inv() * sp.Matrix([L,Psi])
newvars = [y1,y2,x1,x2,D_exprn]
subsrule = dict(zip([L,Psi],mtrx * sp.Matrix([D,L2res])))

newvars, subsrule
# Out:
# ⎛⎡                     Ψ⋅(ρ + 1)⎤                                       ⎞
# ⎜⎢y₁, y₂, x₁, x₂, -L + ─────────⎥, {L: -D + L₂⋅(ρ + 1), Ψ: L₂⋅(3⋅ρ + 2)}⎟
# ⎝⎣                      3⋅ρ + 2 ⎦                                       ⎠

# %%
from sympy.simplify.fu import TR10,TR10i,TR11

mtrx_func = lambda i,j: sp.simplify(TR10i(TR10(sp.diff(ct_all.new_to_old(newvars[i]),oldvars[j]))))
jac_old = sp.Matrix(len(newvars),len(oldvars),mtrx_func)

newdisflow = sp.simplify(ct_all.old_to_new(jac_old * disflow))
jac_old, newdisflow
# Out:
# ⎛
# ⎜
# ⎜
# ⎜
# ⎜
# ⎜
# ⎜⎡-2⋅η₁⋅sin(2⋅λ₁ - 3⋅λ₂) - 2⋅κ₁⋅cos(2⋅λ₁ - 3⋅λ₂)  cos(2⋅λ₁ - 3⋅λ₂)  0  3⋅η₁⋅si
# ⎜⎢
# ⎜⎢-2⋅η₂⋅sin(2⋅λ₁ - 3⋅λ₂) - 2⋅κ₂⋅cos(2⋅λ₁ - 3⋅λ₂)         0          0  3⋅η₂⋅si
# ⎜⎢
# ⎜⎢2⋅η₁⋅cos(2⋅λ₁ - 3⋅λ₂) - 2⋅κ₁⋅sin(2⋅λ₁ - 3⋅λ₂)   sin(2⋅λ₁ - 3⋅λ₂)  0  -3⋅η₁⋅c
# ⎜⎢
# ⎜⎢2⋅η₂⋅cos(2⋅λ₁ - 3⋅λ₂) - 2⋅κ₂⋅sin(2⋅λ₁ - 3⋅λ₂)          0          0  -3⋅η₂⋅c
# ⎜⎢
# ⎜⎢
# ⎜⎢                      0                                η₁         0
# ⎜⎣
# ⎜
# ⎜
# ⎜
# ⎜
# ⎝
#
#
#
#
#
#
#
# n(2⋅λ₁ - 3⋅λ₂) + 3⋅κ₁⋅cos(2⋅λ₁ - 3⋅λ₂)          0          0     0     -sin(2⋅
#
# n(2⋅λ₁ - 3⋅λ₂) + 3⋅κ₂⋅cos(2⋅λ₁ - 3⋅λ₂)   cos(2⋅λ₁ - 3⋅λ₂)  0     0
#
# os(2⋅λ₁ - 3⋅λ₂) + 3⋅κ₁⋅sin(2⋅λ₁ - 3⋅λ₂)         0          0     0     cos(2⋅λ
#
# os(2⋅λ₁ - 3⋅λ₂) + 3⋅κ₂⋅sin(2⋅λ₁ - 3⋅λ₂)  sin(2⋅λ₁ - 3⋅λ₂)  0     0
#
#                                                                  1
#                0                                η₂         0  ───────
#                                                               3⋅ρ + 2
#
#
#
#
#
#
#                                                ⎡
#                                                ⎢
#                                                ⎢
#                                                ⎢
#                                                ⎢
#                                                ⎢
# λ₁ - 3⋅λ₂)  0     0             0          0⎤  ⎢
#                                             ⎥  ⎢
#  0          0     0     -sin(2⋅λ₁ - 3⋅λ₂)  0⎥  ⎢
#                                             ⎥  ⎢
# ₁ - 3⋅λ₂)   0     0             0          0⎥  ⎢
#                                             ⎥, ⎢
#  0          0     0     cos(2⋅λ₁ - 3⋅λ₂)   0⎥  ⎢
#                                             ⎥  ⎢
#                  -ρ                         ⎥  ⎢
# κ₁          0  ───────         κ₂          0⎥  ⎢
#                3⋅ρ + 2                      ⎦  ⎢              ⎛
#                                                ⎢ρ⋅τₐ₁⋅τₑ₁⋅τₑ₂⋅⎝6⋅L - 2⋅Ψ + 3⋅x
#                                                ⎢──────────────────────────────
#                                                ⎢                            4
#                                                ⎢──────────────────────────────
#                                                ⎣
#
#                                                         -y₁
#                                                         ────
#                                                         τₑ₁
#
#                                                         -y₂
#                                                         ────
#                                                         τₑ₂
#
#                                                         -x₁
#                                                         ────
#                                                         τₑ₁
#
#                                                         -x₂
#                                                         ────
#                                                         τₑ₂
#
#  2       2       2       2⎞
# ₁  + 3⋅x₂  + 3⋅y₁  + 3⋅y₂ ⎠                         ⎛  2     2⎞
# ─────────────────────────── - τₐ₁⋅τₐ₂⋅τₑ₁⋅(3⋅ρ + 2)⋅⎝x₂  + y₂ ⎠ - τₐ₁⋅τₐ₂⋅τₑ₂⋅
#
# ──────────────────────────────────────────────────────────────────────────────
#                                               τₐ₁⋅τₐ₂⋅τₑ₁⋅τₑ₂⋅(3⋅ρ + 2)
#
#                                                                      ⎤⎞
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                                                      ⎥⎟
#                                     ⎛            2     2     2     2⎞⎥⎟
#           ⎛  2     2⎞   τₐ₂⋅τₑ₁⋅τₑ₂⋅⎝2⋅L - Ψ + x₁  + x₂  + y₁  + y₂ ⎠⎥⎟
# (3⋅ρ + 2)⋅⎝x₁  + y₁ ⎠ + ─────────────────────────────────────────────⎥⎟
#                                               2                      ⎥⎟
# ─────────────────────────────────────────────────────────────────────⎥⎟
#                                                                      ⎦⎠

# %%
newdisflow = newdisflow.subs(subsrule)
newdisflow
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢              ⎛                                           2       2       2
# ⎢ρ⋅τₐ₁⋅τₑ₁⋅τₑ₂⋅⎝-6⋅D + 6⋅L₂⋅(ρ + 1) - 2⋅L₂⋅(3⋅ρ + 2) + 3⋅x₁  + 3⋅x₂  + 3⋅y₁  +
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢                                         4
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎣
#
#                                     -y₁
#                                     ────
#                                     τₑ₁
#
#                                     -y₂
#                                     ────
#                                     τₑ₂
#
#                                     -x₁
#                                     ────
#                                     τₑ₁
#
#                                     -x₂
#                                     ────
#                                     τₑ₂
#
#      2⎞
#  3⋅y₂ ⎠                         ⎛  2     2⎞                         ⎛  2     2
# ─────── - τₐ₁⋅τₐ₂⋅τₑ₁⋅(3⋅ρ + 2)⋅⎝x₂  + y₂ ⎠ - τₐ₁⋅τₐ₂⋅τₑ₂⋅(3⋅ρ + 2)⋅⎝x₁  + y₁
#
# ──────────────────────────────────────────────────────────────────────────────
#                           τₐ₁⋅τₐ₂⋅τₑ₁⋅τₑ₂⋅(3⋅ρ + 2)
#
#                                                                             ⎤
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                                                                             ⎥
#                 ⎛                                       2     2     2     2⎞⎥
# ⎞   τₐ₂⋅τₑ₁⋅τₑ₂⋅⎝-2⋅D + 2⋅L₂⋅(ρ + 1) - L₂⋅(3⋅ρ + 2) + x₁  + x₂  + y₁  + y₂ ⎠⎥
# ⎠ + ────────────────────────────────────────────────────────────────────────⎥
#                                        2                                    ⎥
# ────────────────────────────────────────────────────────────────────────────⎥
#                                                                             ⎦

# %%
p1 = (x1*x1 + y1*y1)/sp.S(2)
p2 = (x2*x2 + y2*y2)/sp.S(2)
factor = rho * L2res / (3*rho+2)
tau_alpha = 1/(1/tau_a1 - 1/tau_a2)
Ddot_dis = factor *(1/sp.S(2))* 1/tau_alpha - p1/tau_e1 - p2/tau_e2
newdisflow_approx = sp.Matrix([(newdisflow[i] if i<4 else Ddot_dis) for i in range(5)])


Ddot_dis
# Out:
#                        2     2     2     2
#      ⎛   1     1 ⎞   x₂    y₂    x₁    y₁
# L₂⋅ρ⋅⎜- ─── + ───⎟   ─── + ───   ─── + ───
#      ⎝  τₐ₂   τₐ₁⎠    2     2     2     2
# ────────────────── - ───────── - ─────────
#    2⋅(3⋅ρ + 2)          τₑ₂         τₑ₁

# %%
newdisflow_approx
# Out:
# ⎡                   -y₁                    ⎤
# ⎢                   ────                   ⎥
# ⎢                   τₑ₁                    ⎥
# ⎢                                          ⎥
# ⎢                   -y₂                    ⎥
# ⎢                   ────                   ⎥
# ⎢                   τₑ₂                    ⎥
# ⎢                                          ⎥
# ⎢                   -x₁                    ⎥
# ⎢                   ────                   ⎥
# ⎢                   τₑ₁                    ⎥
# ⎢                                          ⎥
# ⎢                   -x₂                    ⎥
# ⎢                   ────                   ⎥
# ⎢                   τₑ₂                    ⎥
# ⎢                                          ⎥
# ⎢                       2     2     2     2⎥
# ⎢     ⎛   1     1 ⎞   x₂    y₂    x₁    y₁ ⎥
# ⎢L₂⋅ρ⋅⎜- ─── + ───⎟   ─── + ───   ─── + ───⎥
# ⎢     ⎝  τₐ₂   τₐ₁⎠    2     2     2     2 ⎥
# ⎢────────────────── - ───────── - ─────────⎥
# ⎣   2⋅(3⋅ρ + 2)          τₑ₂         τₑ₁   ⎦

# %%
ham2.qp_vars
# Out:
# [y₁, y₂, x₁, x₂]

# %% [markdown]
# We'll want to use the following as our set of dynamical variables:

# %%
dyvars = [y1,y2,x1,x2,D]

# %% [markdown]
# We'll need to substitute the following numerical values into our equations of motion in a few places:

# %%
L2res_val=L2res_exprn.subs(ham2.full_qp).subs({rho:rho_val})
newpars =dict()
newpars[L2res] = L2res_val
newpars[rho] = rho_val
newpars
# Out:
# {L₂: 6.20418517141002e-5, ρ: 0.8733792811942415}

# %% [markdown]
# conservative flow expressed in term of dynamical variables (need to augment with $\dot{D}=0$)

# %%
ham2.flow
# Out:
# ⎡
# ⎢  C_{(3,-2,-1,0,0,0)}_{1,2})__{(0,0,0,0),(0,0)}(\alpha⋅G⋅m₁⋅m₂
# ⎢- ──────────────────────────────────────────────────────────── - ────────────
# ⎢                     _______________
# ⎢                   ╲╱ \Lambda_{1,0} ⋅a_{2,0}                     ⎛   2
# ⎢                                                                 ⎝8⋅L  - 8⋅L⋅
# ⎢
# ⎢
# ⎢  C_{(3,-2,0,-1,0,0)}_{1,2})__{(0,0,0,0),(0,0)}(\alpha⋅G⋅m₁⋅m₂
# ⎢- ──────────────────────────────────────────────────────────── - ────────────
# ⎢                     _______________
# ⎢                   ╲╱ \Lambda_{2,0} ⋅a_{2,0}                     ⎛   2
# ⎢                                                                 ⎝8⋅L  - 8⋅L⋅
# ⎢
# ⎢
# ⎢
# ⎢                                ─────────────────────────────────────────────
# ⎢
# ⎢                                ⎛   2                 2         2         2
# ⎢                                ⎝8⋅L  - 8⋅L⋅Ψ + 8⋅L⋅x₁  + 8⋅L⋅x₂  + 8⋅L⋅y₁  +
# ⎢
# ⎢
# ⎢
# ⎢                                ─────────────────────────────────────────────
# ⎢
# ⎢                                ⎛   2                 2         2         2
# ⎣                                ⎝8⋅L  - 8⋅L⋅Ψ + 8⋅L⋅x₁  + 8⋅L⋅x₂  + 8⋅L⋅y₁  +
#
#                                                         2   2   3 ⎛
#                                                        G ⋅M₁ ⋅μ₁ ⋅⎝-16⋅L⋅x₁ +
# ──────────────────────────────────────────────────────────────────────────────
#
#           2         2         2         2      2         2         2         2
# Ψ + 8⋅L⋅x₁  + 8⋅L⋅x₂  + 8⋅L⋅y₁  + 8⋅L⋅y₂  + 2⋅Ψ  - 4⋅Ψ⋅x₁  - 4⋅Ψ⋅x₂  - 4⋅Ψ⋅y₁
#
#                                                         2   2   3 ⎛
#                                                        G ⋅M₁ ⋅μ₁ ⋅⎝-16⋅L⋅x₂ +
# ──────────────────────────────────────────────────────────────────────────────
#
#           2         2         2         2      2         2         2         2
# Ψ + 8⋅L⋅x₁  + 8⋅L⋅x₂  + 8⋅L⋅y₁  + 8⋅L⋅y₂  + 2⋅Ψ  - 4⋅Ψ⋅x₁  - 4⋅Ψ⋅x₂  - 4⋅Ψ⋅y₁
#
#                        2   2   3 ⎛                        2          2
#                       G ⋅M₁ ⋅μ₁ ⋅⎝-16⋅L⋅y₁ + 8⋅Ψ⋅y₁ - 8⋅x₁ ⋅y₁ - 8⋅x₂ ⋅y₁ - 8⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#        2      2         2         2         2         2       4       2   2
#  8⋅L⋅y₂  + 2⋅Ψ  - 4⋅Ψ⋅x₁  - 4⋅Ψ⋅x₂  - 4⋅Ψ⋅y₁  - 4⋅Ψ⋅y₂  + 2⋅x₁  + 4⋅x₁ ⋅x₂  +
#
#                        2   2   3 ⎛                        2          2
#                       G ⋅M₁ ⋅μ₁ ⋅⎝-16⋅L⋅y₂ + 8⋅Ψ⋅y₂ - 8⋅x₁ ⋅y₂ - 8⋅x₂ ⋅y₂ - 8⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#        2      2         2         2         2         2       4       2   2
#  8⋅L⋅y₂  + 2⋅Ψ  - 4⋅Ψ⋅x₁  - 4⋅Ψ⋅x₂  - 4⋅Ψ⋅y₁  - 4⋅Ψ⋅y₂  + 2⋅x₁  + 4⋅x₁ ⋅x₂  +
#
#              3          2          2          2⎞
# 8⋅Ψ⋅x₁ - 8⋅x₁  - 8⋅x₁⋅x₂  - 8⋅x₁⋅y₁  - 8⋅x₁⋅y₂ ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#          2       4       2   2       2   2       2   2       4       2   2
#  - 4⋅Ψ⋅y₂  + 2⋅x₁  + 4⋅x₁ ⋅x₂  + 4⋅x₁ ⋅y₁  + 4⋅x₁ ⋅y₂  + 2⋅x₂  + 4⋅x₂ ⋅y₁  + 4
#
#              2          3          2          2⎞
# 8⋅Ψ⋅x₂ - 8⋅x₁ ⋅x₂ - 8⋅x₂  - 8⋅x₂⋅y₁  - 8⋅x₂⋅y₂ ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#          2       4       2   2       2   2       2   2       4       2   2
#  - 4⋅Ψ⋅y₂  + 2⋅x₁  + 4⋅x₁ ⋅x₂  + 4⋅x₁ ⋅y₁  + 4⋅x₁ ⋅y₂  + 2⋅x₂  + 4⋅x₂ ⋅y₁  + 4
#
#   3          2⎞
# y₁  - 8⋅y₁⋅y₂ ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#     2   2       2   2       4       2   2       2   2       4       2   2
# 4⋅x₁ ⋅y₁  + 4⋅x₁ ⋅y₂  + 2⋅x₂  + 4⋅x₂ ⋅y₁  + 4⋅x₂ ⋅y₂  + 2⋅y₁  + 4⋅y₁ ⋅y₂  + 2⋅
#
#   2          3⎞
# y₁ ⋅y₂ - 8⋅y₂ ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#     2   2       2   2       4       2   2       2   2       4       2   2
# 4⋅x₁ ⋅y₁  + 4⋅x₁ ⋅y₂  + 2⋅x₂  + 4⋅x₂ ⋅y₁  + 4⋅x₂ ⋅y₂  + 2⋅y₁  + 4⋅y₁ ⋅y₂  + 2⋅
#
#
#
# ────────────────────────────────────── - ─────────────────────────────────────
#                                      2
#    2   2       4       2   2       4⎞    ⎛    2                   2          2
# ⋅x₂ ⋅y₂  + 2⋅y₁  + 4⋅y₁ ⋅y₂  + 2⋅y₂ ⎠    ⎝36⋅L  - 24⋅L⋅Ψ + 36⋅L⋅x₁  + 36⋅L⋅x₂
#
#
#
# ────────────────────────────────────── - ─────────────────────────────────────
#                                      2
#    2   2       4       2   2       4⎞    ⎛    2                   2          2
# ⋅x₂ ⋅y₂  + 2⋅y₁  + 4⋅y₁ ⋅y₂  + 2⋅y₂ ⎠    ⎝36⋅L  - 24⋅L⋅Ψ + 36⋅L⋅x₁  + 36⋅L⋅x₂
#
#
#
# ───── + ──────────────────────────────────────────────────────────────────────
#     2
#   4⎞    ⎛    2                   2          2          2          2      2
# y₂ ⎠    ⎝36⋅L  - 24⋅L⋅Ψ + 36⋅L⋅x₁  + 36⋅L⋅x₂  + 36⋅L⋅y₁  + 36⋅L⋅y₂  + 4⋅Ψ  - 1
#
#
#
# ───── + ──────────────────────────────────────────────────────────────────────
#     2
#   4⎞    ⎛    2                   2          2          2          2      2
# y₂ ⎠    ⎝36⋅L  - 24⋅L⋅Ψ + 36⋅L⋅x₁  + 36⋅L⋅x₂  + 36⋅L⋅y₁  + 36⋅L⋅y₂  + 4⋅Ψ  - 1
#
#                                       2   2   3 ⎛                          3
#                                    2⋅G ⋅M₂ ⋅μ₂ ⋅⎝-72⋅L⋅x₁ + 24⋅Ψ⋅x₁ - 36⋅x₁  -
# ──────────────────────────────────────────────────────────────────────────────
#
#           2          2      2          2          2          2          2
#  + 36⋅L⋅y₁  + 36⋅L⋅y₂  + 4⋅Ψ  - 12⋅Ψ⋅x₁  - 12⋅Ψ⋅x₂  - 12⋅Ψ⋅y₁  - 12⋅Ψ⋅y₂  + 9⋅
#
#                                       2   2   3 ⎛                          2
#                                    2⋅G ⋅M₂ ⋅μ₂ ⋅⎝-72⋅L⋅x₂ + 24⋅Ψ⋅x₂ - 36⋅x₁ ⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#           2          2      2          2          2          2          2
#  + 36⋅L⋅y₁  + 36⋅L⋅y₂  + 4⋅Ψ  - 12⋅Ψ⋅x₁  - 12⋅Ψ⋅x₂  - 12⋅Ψ⋅y₁  - 12⋅Ψ⋅y₂  + 9⋅
#
#      2   2   3 ⎛                          2           2           3
#   2⋅G ⋅M₂ ⋅μ₂ ⋅⎝-72⋅L⋅y₁ + 24⋅Ψ⋅y₁ - 36⋅x₁ ⋅y₁ - 36⋅x₂ ⋅y₁ - 36⋅y₁  - 36⋅y₁⋅y₂
# ──────────────────────────────────────────────────────────────────────────────
#
#       2          2          2          2       4        2   2        2   2
# 2⋅Ψ⋅x₁  - 12⋅Ψ⋅x₂  - 12⋅Ψ⋅y₁  - 12⋅Ψ⋅y₂  + 9⋅x₁  + 18⋅x₁ ⋅x₂  + 18⋅x₁ ⋅y₁  + 1
#
#      2   2   3 ⎛                          2           2           2
#   2⋅G ⋅M₂ ⋅μ₂ ⋅⎝-72⋅L⋅y₂ + 24⋅Ψ⋅y₂ - 36⋅x₁ ⋅y₂ - 36⋅x₂ ⋅y₂ - 36⋅y₁ ⋅y₂ - 36⋅y₂
# ──────────────────────────────────────────────────────────────────────────────
#
#       2          2          2          2       4        2   2        2   2
# 2⋅Ψ⋅x₁  - 12⋅Ψ⋅x₂  - 12⋅Ψ⋅y₁  - 12⋅Ψ⋅y₂  + 9⋅x₁  + 18⋅x₁ ⋅x₂  + 18⋅x₁ ⋅y₁  + 1
#
#          2           2           2⎞
#  36⋅x₁⋅x₂  - 36⋅x₁⋅y₁  - 36⋅x₁⋅y₂ ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#   4        2   2        2   2        2   2       4        2   2        2   2
# x₁  + 18⋅x₁ ⋅x₂  + 18⋅x₁ ⋅y₁  + 18⋅x₁ ⋅y₂  + 9⋅x₂  + 18⋅x₂ ⋅y₁  + 18⋅x₂ ⋅y₂  +
#
#          3           2           2⎞
# ₂ - 36⋅x₂  - 36⋅x₂⋅y₁  - 36⋅x₂⋅y₂ ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#   4        2   2        2   2        2   2       4        2   2        2   2
# x₁  + 18⋅x₁ ⋅x₂  + 18⋅x₁ ⋅y₁  + 18⋅x₁ ⋅y₂  + 9⋅x₂  + 18⋅x₂ ⋅y₁  + 18⋅x₂ ⋅y₂  +
#
# 2⎞
#  ⎠
# ──────────────────────────────────────────────────────────────────────────
#                                                                          2
#     2   2       4        2   2        2   2       4        2   2       4⎞
# 8⋅x₁ ⋅y₂  + 9⋅x₂  + 18⋅x₂ ⋅y₁  + 18⋅x₂ ⋅y₂  + 9⋅y₁  + 18⋅y₁ ⋅y₂  + 9⋅y₂ ⎠
#
# 3⎞
#  ⎠
# ──────────────────────────────────────────────────────────────────────────
#                                                                          2
#     2   2       4        2   2        2   2       4        2   2       4⎞
# 8⋅x₁ ⋅y₂  + 9⋅x₂  + 18⋅x₂ ⋅y₁  + 18⋅x₂ ⋅y₂  + 9⋅y₁  + 18⋅y₁ ⋅y₂  + 9⋅y₂ ⎠
#
#                              ⎤
#                              ⎥
# ─────────────────────────────⎥
#                             2⎥
#      4        2   2       4⎞ ⎥
#  9⋅y₁  + 18⋅y₁ ⋅y₂  + 9⋅y₂ ⎠ ⎥
#                              ⎥
#                              ⎥
#                              ⎥
# ─────────────────────────────⎥
#                             2⎥
#      4        2   2       4⎞ ⎥
#  9⋅y₁  + 18⋅y₁ ⋅y₂  + 9⋅y₂ ⎠ ⎥
#                              ⎥
#                              ⎥
#                              ⎥
#                              ⎥
#                              ⎥
#                              ⎥
#                              ⎥
#                              ⎥
#                              ⎥
#                              ⎥
#                              ⎥
#                              ⎥
#                              ⎥
#                              ⎦

# %%
ham2.flow.subs(subsrule)
# Out:
# ⎡
# ⎢  C_{(3,-2,-1,0,0,0)}_{1,2})__{(0,0,0,0),(0,0)}(\alpha⋅G⋅m₁⋅m₂
# ⎢- ──────────────────────────────────────────────────────────── - ────────────
# ⎢                     _______________
# ⎢                   ╲╱ \Lambda_{1,0} ⋅a_{2,0}                     ⎛    2
# ⎢                                                                 ⎝2⋅L₂ ⋅(3⋅ρ
# ⎢
# ⎢
# ⎢  C_{(3,-2,0,-1,0,0)}_{1,2})__{(0,0,0,0),(0,0)}(\alpha⋅G⋅m₁⋅m₂
# ⎢- ──────────────────────────────────────────────────────────── - ────────────
# ⎢                     _______________
# ⎢                   ╲╱ \Lambda_{2,0} ⋅a_{2,0}                     ⎛    2
# ⎢                                                                 ⎝2⋅L₂ ⋅(3⋅ρ
# ⎢
# ⎢
# ⎢
# ⎢                                ─────────────────────────────────────────────
# ⎢
# ⎢                                ⎛    2          2          2
# ⎢                                ⎝2⋅L₂ ⋅(3⋅ρ + 2)  - 4⋅L₂⋅x₁ ⋅(3⋅ρ + 2) - 4⋅L₂
# ⎢
# ⎢
# ⎢
# ⎢                                ─────────────────────────────────────────────
# ⎢
# ⎢                                ⎛    2          2          2
# ⎣                                ⎝2⋅L₂ ⋅(3⋅ρ + 2)  - 4⋅L₂⋅x₁ ⋅(3⋅ρ + 2) - 4⋅L₂
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#     2          2                    2                    2
# + 2)  - 4⋅L₂⋅x₁ ⋅(3⋅ρ + 2) - 4⋅L₂⋅x₂ ⋅(3⋅ρ + 2) - 4⋅L₂⋅y₁ ⋅(3⋅ρ + 2) - 4⋅L₂⋅y₂
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#     2          2                    2                    2
# + 2)  - 4⋅L₂⋅x₁ ⋅(3⋅ρ + 2) - 4⋅L₂⋅x₂ ⋅(3⋅ρ + 2) - 4⋅L₂⋅y₁ ⋅(3⋅ρ + 2) - 4⋅L₂⋅y₂
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#    2                    2                    2
# ⋅x₂ ⋅(3⋅ρ + 2) - 4⋅L₂⋅y₁ ⋅(3⋅ρ + 2) - 4⋅L₂⋅y₂ ⋅(3⋅ρ + 2) - 8⋅L₂⋅(-D + L₂⋅(ρ +
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#    2                    2                    2
# ⋅x₂ ⋅(3⋅ρ + 2) - 4⋅L₂⋅y₁ ⋅(3⋅ρ + 2) - 4⋅L₂⋅y₂ ⋅(3⋅ρ + 2) - 8⋅L₂⋅(-D + L₂⋅(ρ +
#
#                                                2   2   3 ⎛
#                                               G ⋅M₁ ⋅μ₁ ⋅⎝8⋅L₂⋅x₁⋅(3⋅ρ + 2) -
# ──────────────────────────────────────────────────────────────────────────────
#
# 2                                                    4       2   2       2   2
#  ⋅(3⋅ρ + 2) - 8⋅L₂⋅(-D + L₂⋅(ρ + 1))⋅(3⋅ρ + 2) + 2⋅x₁  + 4⋅x₁ ⋅x₂  + 4⋅x₁ ⋅y₁
#
#                                                2   2   3 ⎛
#                                               G ⋅M₁ ⋅μ₁ ⋅⎝8⋅L₂⋅x₂⋅(3⋅ρ + 2) -
# ──────────────────────────────────────────────────────────────────────────────
#
# 2                                                    4       2   2       2   2
#  ⋅(3⋅ρ + 2) - 8⋅L₂⋅(-D + L₂⋅(ρ + 1))⋅(3⋅ρ + 2) + 2⋅x₁  + 4⋅x₁ ⋅x₂  + 4⋅x₁ ⋅y₁
#
#               2   2   3 ⎛                        2          2          3
#              G ⋅M₁ ⋅μ₁ ⋅⎝8⋅L₂⋅y₁⋅(3⋅ρ + 2) - 8⋅x₁ ⋅y₁ - 8⋅x₂ ⋅y₁ - 8⋅y₁  - 8⋅y
# ──────────────────────────────────────────────────────────────────────────────
#
#                     4       2   2       2   2       2   2       2
# 1))⋅(3⋅ρ + 2) + 2⋅x₁  + 4⋅x₁ ⋅x₂  + 4⋅x₁ ⋅y₁  + 4⋅x₁ ⋅y₂  + 8⋅x₁ ⋅(-D + L₂⋅(ρ
#
#               2   2   3 ⎛                        2          2          2
#              G ⋅M₁ ⋅μ₁ ⋅⎝8⋅L₂⋅y₂⋅(3⋅ρ + 2) - 8⋅x₁ ⋅y₂ - 8⋅x₂ ⋅y₂ - 8⋅y₁ ⋅y₂ -
# ──────────────────────────────────────────────────────────────────────────────
#
#                     4       2   2       2   2       2   2       2
# 1))⋅(3⋅ρ + 2) + 2⋅x₁  + 4⋅x₁ ⋅x₂  + 4⋅x₁ ⋅y₁  + 4⋅x₁ ⋅y₂  + 8⋅x₁ ⋅(-D + L₂⋅(ρ
#
#     3          2          2          2                          ⎞
# 8⋅x₁  - 8⋅x₁⋅x₂  - 8⋅x₁⋅y₁  - 8⋅x₁⋅y₂  - 16⋅x₁⋅(-D + L₂⋅(ρ + 1))⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#        2   2       2                         4       2   2       2   2       2
#  + 4⋅x₁ ⋅y₂  + 8⋅x₁ ⋅(-D + L₂⋅(ρ + 1)) + 2⋅x₂  + 4⋅x₂ ⋅y₁  + 4⋅x₂ ⋅y₂  + 8⋅x₂
#
#     2          3          2          2                          ⎞
# 8⋅x₁ ⋅x₂ - 8⋅x₂  - 8⋅x₂⋅y₁  - 8⋅x₂⋅y₂  - 16⋅x₂⋅(-D + L₂⋅(ρ + 1))⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#        2   2       2                         4       2   2       2   2       2
#  + 4⋅x₁ ⋅y₂  + 8⋅x₁ ⋅(-D + L₂⋅(ρ + 1)) + 2⋅x₂  + 4⋅x₂ ⋅y₁  + 4⋅x₂ ⋅y₂  + 8⋅x₂
#
#     2                          ⎞
# ₁⋅y₂  - 16⋅y₁⋅(-D + L₂⋅(ρ + 1))⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#             4       2   2       2   2       2                         4
# + 1)) + 2⋅x₂  + 4⋅x₂ ⋅y₁  + 4⋅x₂ ⋅y₂  + 8⋅x₂ ⋅(-D + L₂⋅(ρ + 1)) + 2⋅y₁  + 4⋅y₁
#
#     3                          ⎞
# 8⋅y₂  - 16⋅y₂⋅(-D + L₂⋅(ρ + 1))⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#             4       2   2       2   2       2                         4
# + 1)) + 2⋅x₂  + 4⋅x₂ ⋅y₁  + 4⋅x₂ ⋅y₂  + 8⋅x₂ ⋅(-D + L₂⋅(ρ + 1)) + 2⋅y₁  + 4⋅y₁
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                          4       2   2       2                         4
# ⋅(-D + L₂⋅(ρ + 1)) + 2⋅y₁  + 4⋅y₁ ⋅y₂  + 8⋅y₁ ⋅(-D + L₂⋅(ρ + 1)) + 2⋅y₂  + 8⋅y
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                          4       2   2       2                         4
# ⋅(-D + L₂⋅(ρ + 1)) + 2⋅y₁  + 4⋅y₁ ⋅y₂  + 8⋅y₁ ⋅(-D + L₂⋅(ρ + 1)) + 2⋅y₂  + 8⋅y
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# 2   2       2                         4       2
#  ⋅y₂  + 8⋅y₁ ⋅(-D + L₂⋅(ρ + 1)) + 2⋅y₂  + 8⋅y₂ ⋅(-D + L₂⋅(ρ + 1)) + 8⋅(-D + L₂
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# 2   2       2                         4       2
#  ⋅y₂  + 8⋅y₁ ⋅(-D + L₂⋅(ρ + 1)) + 2⋅y₂  + 8⋅y₂ ⋅(-D + L₂⋅(ρ + 1)) + 8⋅(-D + L₂
#
#
#
# ───────────────────────────────────────────── - ──────────────────────────────
#                                             2
#  2                                        2⎞    ⎛    2          2           2
# ₂ ⋅(-D + L₂⋅(ρ + 1)) + 8⋅(-D + L₂⋅(ρ + 1)) ⎠    ⎝4⋅L₂ ⋅(3⋅ρ + 2)  - 12⋅L₂⋅x₁ ⋅
#
#
#
# ───────────────────────────────────────────── - ──────────────────────────────
#                                             2
#  2                                        2⎞    ⎛    2          2           2
# ₂ ⋅(-D + L₂⋅(ρ + 1)) + 8⋅(-D + L₂⋅(ρ + 1)) ⎠    ⎝4⋅L₂ ⋅(3⋅ρ + 2)  - 12⋅L₂⋅x₁ ⋅
#
#
#
# ──────────── + ───────────────────────────────────────────────────────────────
#            2
#          2⎞    ⎛    2          2           2                     2
# ⋅(ρ + 1)) ⎠    ⎝4⋅L₂ ⋅(3⋅ρ + 2)  - 12⋅L₂⋅x₁ ⋅(3⋅ρ + 2) - 12⋅L₂⋅x₂ ⋅(3⋅ρ + 2) -
#
#
#
# ──────────── + ───────────────────────────────────────────────────────────────
#            2
#          2⎞    ⎛    2          2           2                     2
# ⋅(ρ + 1)) ⎠    ⎝4⋅L₂ ⋅(3⋅ρ + 2)  - 12⋅L₂⋅x₁ ⋅(3⋅ρ + 2) - 12⋅L₂⋅x₂ ⋅(3⋅ρ + 2) -
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                     2                     2                     2
# (3⋅ρ + 2) - 12⋅L₂⋅x₂ ⋅(3⋅ρ + 2) - 12⋅L₂⋅y₁ ⋅(3⋅ρ + 2) - 12⋅L₂⋅y₂ ⋅(3⋅ρ + 2) -
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                     2                     2                     2
# (3⋅ρ + 2) - 12⋅L₂⋅x₂ ⋅(3⋅ρ + 2) - 12⋅L₂⋅y₁ ⋅(3⋅ρ + 2) - 12⋅L₂⋅y₂ ⋅(3⋅ρ + 2) -
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#          2                     2
#  12⋅L₂⋅y₁ ⋅(3⋅ρ + 2) - 12⋅L₂⋅y₂ ⋅(3⋅ρ + 2) - 24⋅L₂⋅(-D + L₂⋅(ρ + 1))⋅(3⋅ρ + 2)
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#          2                     2
#  12⋅L₂⋅y₁ ⋅(3⋅ρ + 2) - 12⋅L₂⋅y₂ ⋅(3⋅ρ + 2) - 24⋅L₂⋅(-D + L₂⋅(ρ + 1))⋅(3⋅ρ + 2)
#
#                                     2   2   3 ⎛                          3
#                                  2⋅G ⋅M₂ ⋅μ₂ ⋅⎝24⋅L₂⋅x₁⋅(3⋅ρ + 2) - 36⋅x₁  - 3
# ──────────────────────────────────────────────────────────────────────────────
#
#                                         4        2   2        2   2        2
# 24⋅L₂⋅(-D + L₂⋅(ρ + 1))⋅(3⋅ρ + 2) + 9⋅x₁  + 18⋅x₁ ⋅x₂  + 18⋅x₁ ⋅y₁  + 18⋅x₁ ⋅y
#
#                                     2   2   3 ⎛                          2
#                                  2⋅G ⋅M₂ ⋅μ₂ ⋅⎝24⋅L₂⋅x₂⋅(3⋅ρ + 2) - 36⋅x₁ ⋅x₂
# ──────────────────────────────────────────────────────────────────────────────
#
#                                         4        2   2        2   2        2
# 24⋅L₂⋅(-D + L₂⋅(ρ + 1))⋅(3⋅ρ + 2) + 9⋅x₁  + 18⋅x₁ ⋅x₂  + 18⋅x₁ ⋅y₁  + 18⋅x₁ ⋅y
#
#    2   2   3 ⎛                          2           2           3           2
# 2⋅G ⋅M₂ ⋅μ₂ ⋅⎝24⋅L₂⋅y₁⋅(3⋅ρ + 2) - 36⋅x₁ ⋅y₁ - 36⋅x₂ ⋅y₁ - 36⋅y₁  - 36⋅y₁⋅y₂
# ──────────────────────────────────────────────────────────────────────────────
#
#        4        2   2        2   2        2   2        2
#  + 9⋅x₁  + 18⋅x₁ ⋅x₂  + 18⋅x₁ ⋅y₁  + 18⋅x₁ ⋅y₂  + 36⋅x₁ ⋅(-D + L₂⋅(ρ + 1)) + 9
#
#    2   2   3 ⎛                          2           2           2           3
# 2⋅G ⋅M₂ ⋅μ₂ ⋅⎝24⋅L₂⋅y₂⋅(3⋅ρ + 2) - 36⋅x₁ ⋅y₂ - 36⋅x₂ ⋅y₂ - 36⋅y₁ ⋅y₂ - 36⋅y₂
# ──────────────────────────────────────────────────────────────────────────────
#
#        4        2   2        2   2        2   2        2
#  + 9⋅x₁  + 18⋅x₁ ⋅x₂  + 18⋅x₁ ⋅y₁  + 18⋅x₁ ⋅y₂  + 36⋅x₁ ⋅(-D + L₂⋅(ρ + 1)) + 9
#
#        2           2           2                          ⎞
# 6⋅x₁⋅x₂  - 36⋅x₁⋅y₁  - 36⋅x₁⋅y₂  - 72⋅x₁⋅(-D + L₂⋅(ρ + 1))⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#  2        2                         4        2   2        2   2        2
# ₂  + 36⋅x₁ ⋅(-D + L₂⋅(ρ + 1)) + 9⋅x₂  + 18⋅x₂ ⋅y₁  + 18⋅x₂ ⋅y₂  + 36⋅x₂ ⋅(-D +
#
#        3           2           2                          ⎞
# - 36⋅x₂  - 36⋅x₂⋅y₁  - 36⋅x₂⋅y₂  - 72⋅x₂⋅(-D + L₂⋅(ρ + 1))⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#  2        2                         4        2   2        2   2        2
# ₂  + 36⋅x₁ ⋅(-D + L₂⋅(ρ + 1)) + 9⋅x₂  + 18⋅x₂ ⋅y₁  + 18⋅x₂ ⋅y₂  + 36⋅x₂ ⋅(-D +
#
#                          ⎞
# - 72⋅y₁⋅(-D + L₂⋅(ρ + 1))⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#    4        2   2        2   2        2                         4        2   2
# ⋅x₂  + 18⋅x₂ ⋅y₁  + 18⋅x₂ ⋅y₂  + 36⋅x₂ ⋅(-D + L₂⋅(ρ + 1)) + 9⋅y₁  + 18⋅y₁ ⋅y₂
#
#                          ⎞
# - 72⋅y₂⋅(-D + L₂⋅(ρ + 1))⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#    4        2   2        2   2        2                         4        2   2
# ⋅x₂  + 18⋅x₂ ⋅y₁  + 18⋅x₂ ⋅y₂  + 36⋅x₂ ⋅(-D + L₂⋅(ρ + 1)) + 9⋅y₁  + 18⋅y₁ ⋅y₂
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                    4        2   2        2                         4        2
#  L₂⋅(ρ + 1)) + 9⋅y₁  + 18⋅y₁ ⋅y₂  + 36⋅y₁ ⋅(-D + L₂⋅(ρ + 1)) + 9⋅y₂  + 36⋅y₂ ⋅
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                    4        2   2        2                         4        2
#  L₂⋅(ρ + 1)) + 9⋅y₁  + 18⋅y₁ ⋅y₂  + 36⋅y₁ ⋅(-D + L₂⋅(ρ + 1)) + 9⋅y₂  + 36⋅y₂ ⋅
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#         2                         4        2
#  + 36⋅y₁ ⋅(-D + L₂⋅(ρ + 1)) + 9⋅y₂  + 36⋅y₂ ⋅(-D + L₂⋅(ρ + 1)) + 36⋅(-D + L₂⋅(
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#         2                         4        2
#  + 36⋅y₁ ⋅(-D + L₂⋅(ρ + 1)) + 9⋅y₂  + 36⋅y₂ ⋅(-D + L₂⋅(ρ + 1)) + 36⋅(-D + L₂⋅(
#
#                                            ⎤
#                                            ⎥
# ───────────────────────────────────────────⎥
#                                           2⎥
#                                         2⎞ ⎥
# (-D + L₂⋅(ρ + 1)) + 36⋅(-D + L₂⋅(ρ + 1)) ⎠ ⎥
#                                            ⎥
#                                            ⎥
#                                            ⎥
# ───────────────────────────────────────────⎥
#                                           2⎥
#                                         2⎞ ⎥
# (-D + L₂⋅(ρ + 1)) + 36⋅(-D + L₂⋅(ρ + 1)) ⎠ ⎥
#                                            ⎥
#                                            ⎥
#                                            ⎥
# ──────────                                 ⎥
#          2                                 ⎥
#        2⎞                                  ⎥
# ρ + 1)) ⎠                                  ⎥
#                                            ⎥
#                                            ⎥
#                                            ⎥
# ──────────                                 ⎥
#          2                                 ⎥
#        2⎞                                  ⎥
# ρ + 1)) ⎠                                  ⎦

# %%
newflow = ham2.flow.subs(subsrule).subs(ham2.H_params).subs(newpars)
newflow
# Out:
# ⎡
# ⎢
# ⎢- ───────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢  ⎛                           4     2   2     2   2     2   2
# ⎢  ⎜                         x₁    x₁ ⋅x₂    x₁ ⋅y₁    x₁ ⋅y₂      2
# ⎢  ⎜0.000191094604660175⋅D + ─── + ─────── + ─────── + ─────── + x₁ ⋅(0.000116
# ⎢  ⎝                          4       2         2         2
# ⎢
# ⎢
# ⎢
# ⎢- ───────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢  ⎛                           4     2   2     2   2     2   2
# ⎢  ⎜                         x₁    x₁ ⋅x₂    x₁ ⋅y₁    x₁ ⋅y₂      2
# ⎢  ⎜0.000191094604660175⋅D + ─── + ─────── + ─────── + ─────── + x₁ ⋅(0.000116
# ⎢  ⎝                          4       2         2         2
# ⎢
# ⎢
# ⎢
# ⎢            ─────────────────────────────────────────────────────────────────
# ⎢
# ⎢            ⎛                           4     2   2     2   2     2   2
# ⎢            ⎜                         x₁    x₁ ⋅x₂    x₁ ⋅y₁    x₁ ⋅y₂      2
# ⎢            ⎜0.000191094604660175⋅D + ─── + ─────── + ─────── + ─────── + x₁
# ⎢            ⎝                          4       2         2         2
# ⎢
# ⎢
# ⎢
# ⎢            ─────────────────────────────────────────────────────────────────
# ⎢
# ⎢            ⎛                           4     2   2     2   2     2   2
# ⎢            ⎜                         x₁    x₁ ⋅x₂    x₁ ⋅y₁    x₁ ⋅y₂      2
# ⎢            ⎜0.000191094604660175⋅D + ─── + ─────── + ─────── + ─────── + x₁
# ⎣            ⎝                          4       2         2         2
#
#
#                                                             1.54305557098611e-
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                 4     2   2     2   2
#                                           2   x₂    x₂ ⋅y₁    x₂ ⋅y₂      2
# 227919568121 - D) - 9.55473023300874e-5⋅x₁  + ─── + ─────── + ─────── + x₂ ⋅(0
#                                                4       2         2
#
#
#                                                             1.54305557098611e-
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                 4     2   2     2   2
#                                           2   x₂    x₂ ⋅y₁    x₂ ⋅y₂      2
# 227919568121 - D) - 9.55473023300874e-5⋅x₁  + ─── + ─────── + ─────── + x₂ ⋅(0
#                                                4       2         2
#
#
#                                                                       1.543055
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                           4     2   2     2
#                                                     2   x₂    x₂ ⋅y₁    x₂ ⋅y₂
# ⋅(0.000116227919568121 - D) - 9.55473023300874e-5⋅x₁  + ─── + ─────── + ──────
#                                                          4       2         2
#
#
#                                                                       1.543055
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                           4     2   2     2
#                                                     2   x₂    x₂ ⋅y₁    x₂ ⋅y₂
# ⋅(0.000116227919568121 - D) - 9.55473023300874e-5⋅x₁  + ─── + ─────── + ──────
#                                                          4       2         2
#
#    ⎛       3           2           2           2
# 15⋅⎝- 36⋅x₁  - 36⋅x₁⋅x₂  - 36⋅x₁⋅y₁  - 36⋅x₁⋅y₂  - 72⋅x₁⋅(0.000116227919568121
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                        4     2   2
#                                                  2   y₁    y₁ ⋅y₂      2
# .000116227919568121 - D) - 9.55473023300874e-5⋅x₂  + ─── + ─────── + y₁ ⋅(0.00
#                                                       4       2
#
#    ⎛       2           3           2           2
# 15⋅⎝- 36⋅x₁ ⋅x₂ - 36⋅x₂  - 36⋅x₂⋅y₁  - 36⋅x₂⋅y₂  - 72⋅x₂⋅(0.000116227919568121
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                        4     2   2
#                                                  2   y₁    y₁ ⋅y₂      2
# .000116227919568121 - D) - 9.55473023300874e-5⋅x₂  + ─── + ─────── + y₁ ⋅(0.00
#                                                       4       2
#
#              ⎛       2           2           3           2
# 57098611e-15⋅⎝- 36⋅x₁ ⋅y₁ - 36⋅x₂ ⋅y₁ - 36⋅y₁  - 36⋅y₁⋅y₂  - 72⋅y₁⋅(0.00011622
# ──────────────────────────────────────────────────────────────────────────────
#
# 2                                                                4     2   2
#       2                                                    2   y₁    y₁ ⋅y₂
# ─ + x₂ ⋅(0.000116227919568121 - D) - 9.55473023300874e-5⋅x₂  + ─── + ─────── +
#                                                                 4       2
#
#              ⎛       2           2           2           3
# 57098611e-15⋅⎝- 36⋅x₁ ⋅y₂ - 36⋅x₂ ⋅y₂ - 36⋅y₁ ⋅y₂ - 36⋅y₂  - 72⋅y₂⋅(0.00011622
# ──────────────────────────────────────────────────────────────────────────────
#
# 2                                                                4     2   2
#       2                                                    2   y₁    y₁ ⋅y₂
# ─ + x₂ ⋅(0.000116227919568121 - D) - 9.55473023300874e-5⋅x₂  + ─── + ─────── +
#                                                                 4       2
#
#                               ⎞
#  - D) + 0.00687940576776629⋅x₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                     4
#                                               2   y₂      2
# 0116227919568121 - D) - 9.55473023300874e-5⋅y₁  + ─── + y₂ ⋅(0.000116227919568
#                                                    4
#
#                               ⎞
#  - D) + 0.00687940576776629⋅x₂⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                     4
#                                               2   y₂      2
# 0116227919568121 - D) - 9.55473023300874e-5⋅y₁  + ─── + y₂ ⋅(0.000116227919568
#                                                    4
#
#                                         ⎞
# 7919568121 - D) + 0.00687940576776629⋅y₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                               4
#    2                                                    2   y₂      2
#  y₁ ⋅(0.000116227919568121 - D) - 9.55473023300874e-5⋅y₁  + ─── + y₂ ⋅(0.00011
#                                                              4
#
#                                         ⎞
# 7919568121 - D) + 0.00687940576776629⋅y₂⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                               4
#    2                                                    2   y₂      2
#  y₁ ⋅(0.000116227919568121 - D) - 9.55473023300874e-5⋅y₁  + ─── + y₂ ⋅(0.00011
#                                                              4
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                  2                             2
# 121 - D) - 9.55473023300874e-5⋅y₂  + (0.000116227919568121 - D)  - 1.308124135
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                  2                             2
# 121 - D) - 9.55473023300874e-5⋅y₂  + (0.000116227919568121 - D)  - 1.308124135
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                            2                             2
# 6227919568121 - D) - 9.55473023300874e-5⋅y₂  + (0.000116227919568121 - D)  - 1
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                            2                             2
# 6227919568121 - D) - 9.55473023300874e-5⋅y₂  + (0.000116227919568121 - D)  - 1
#
#
#
#
# ────────── - ─────────────────────────────────────────────────────────────────
#          2
#         ⎞    ⎛                           4     2   2     2   2     2   2
#         ⎟    ⎜                         x₁    x₁ ⋅x₂    x₁ ⋅y₁    x₁ ⋅y₂      2
# 77875e-8⎟    ⎜0.000286641906990262⋅D + ─── + ─────── + ─────── + ─────── + x₁
#         ⎠    ⎝                          4       2         2         2
#
#
#
# ────────── - ─────────────────────────────────────────────────────────────────
#          2
#         ⎞    ⎛                           4     2   2     2   2     2   2
#         ⎟    ⎜                         x₁    x₁ ⋅x₂    x₁ ⋅y₁    x₁ ⋅y₂      2
# 77875e-8⎟    ⎜0.000286641906990262⋅D + ─── + ─────── + ─────── + ─────── + x₁
#         ⎠    ⎝                          4       2         2         2
#
#
#
# ──────────────────── + ───────────────────────────────────────────────────────
#                    2
#                   ⎞    ⎛                           4     2   2     2   2     2
#                   ⎟    ⎜                         x₁    x₁ ⋅x₂    x₁ ⋅y₁    x₁
# .30812413577875e-8⎟    ⎜0.000286641906990262⋅D + ─── + ─────── + ─────── + ───
#                   ⎠    ⎝                          4       2         2
#
#
#
# ──────────────────── + ───────────────────────────────────────────────────────
#                    2
#                   ⎞    ⎛                           4     2   2     2   2     2
#                   ⎟    ⎜                         x₁    x₁ ⋅x₂    x₁ ⋅y₁    x₁
# .30812413577875e-8⎟    ⎜0.000286641906990262⋅D + ─── + ─────── + ─────── + ───
#                   ⎠    ⎝                          4       2         2
#
#
#                                                                            1.5
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                            4     2   2     2
#                                                      2   x₂    x₂ ⋅y₁    x₂ ⋅y
# ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅x₁  + ─── + ─────── + ─────
#                                                           4       2         2
#
#
#                                                                            1.5
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                            4     2   2     2
#                                                      2   x₂    x₂ ⋅y₁    x₂ ⋅y
# ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅x₁  + ─── + ─────── + ─────
#                                                           4       2         2
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#    2                                                                 4     2
# ⋅y₂      2                                                     2   x₂    x₂ ⋅y
# ──── + x₁ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅x₁  + ─── + ─────
# 2                                                                   4       2
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#    2                                                                 4     2
# ⋅y₂      2                                                     2   x₂    x₂ ⋅y
# ──── + x₁ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅x₁  + ─── + ─────
# 2                                                                   4       2
#
#                   ⎛      3          2          2          2
# 6234376562344e-14⋅⎝- 8⋅x₁  - 8⋅x₁⋅x₂  - 8⋅x₁⋅y₁  - 8⋅x₁⋅y₂  - 16⋅x₁⋅(0.0001162
# ──────────────────────────────────────────────────────────────────────────────
#
#  2                                                                 4     2   2
# ₂      2                                                     2   y₁    y₁ ⋅y₂
# ── + x₂ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅x₂  + ─── + ───────
#                                                                   4       2
#
#                   ⎛      2          3          2          2
# 6234376562344e-14⋅⎝- 8⋅x₁ ⋅x₂ - 8⋅x₂  - 8⋅x₂⋅y₁  - 8⋅x₂⋅y₂  - 16⋅x₂⋅(0.0001162
# ──────────────────────────────────────────────────────────────────────────────
#
#  2                                                                 4     2   2
# ₂      2                                                     2   y₁    y₁ ⋅y₂
# ── + x₂ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅x₂  + ─── + ───────
#                                                                   4       2
#
#                             ⎛      2          2          3          2
#        1.56234376562344e-14⋅⎝- 8⋅x₁ ⋅y₁ - 8⋅x₂ ⋅y₁ - 8⋅y₁  - 8⋅y₁⋅y₂  - 16⋅y₁⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#  2     2   2                                                                 4
# ₁    x₂ ⋅y₂      2                                                     2   y₁
# ── + ─────── + x₂ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅x₂  + ───
#         2                                                                   4
#
#                             ⎛      2          2          2          3
#        1.56234376562344e-14⋅⎝- 8⋅x₁ ⋅y₂ - 8⋅x₂ ⋅y₂ - 8⋅y₁ ⋅y₂ - 8⋅y₂  - 16⋅y₂⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#  2     2   2                                                                 4
# ₁    x₂ ⋅y₂      2                                                     2   y₁
# ── + ─────── + x₂ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅x₂  + ───
#         2                                                                   4
#
#                                         ⎞
# 27919568121 - D) + 0.0022931352559221⋅x₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                  4
#      2                                                     2   y₂      2
#  + y₁ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅y₁  + ─── + y₂ ⋅(0.00
#                                                                 4
#
#                                         ⎞
# 27919568121 - D) + 0.0022931352559221⋅x₂⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                  4
#      2                                                     2   y₂      2
#  + y₁ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅y₁  + ─── + y₂ ⋅(0.00
#                                                                 4
#
#                                                   ⎞
# (0.000116227919568121 - D) + 0.0022931352559221⋅y₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#      2   2                                                                 4
#    y₁ ⋅y₂      2                                                     2   y₂
#  + ─────── + y₁ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅y₁  + ─── +
#       2                                                                   4
#
#                                                   ⎞
# (0.000116227919568121 - D) + 0.0022931352559221⋅y₂⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#      2   2                                                                 4
#    y₁ ⋅y₂      2                                                     2   y₂
#  + ─────── + y₁ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅y₁  + ─── +
#       2                                                                   4
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                2                             2
# 0116227919568121 - D) - 0.000143320953495131⋅y₂  + (0.000116227919568121 - D)
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                2                             2
# 0116227919568121 - D) - 0.000143320953495131⋅y₂  + (0.000116227919568121 - D)
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    2                                                     2
#  y₂ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅y₂  + (0.00011622791956
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    2                                                     2
#  y₂ ⋅(0.000116227919568121 - D) - 0.000143320953495131⋅y₂  + (0.00011622791956
#
#
#                                               ⎤
#                                               ⎥
# ──────────────────────── + 7.13174260934174e-6⎥
#                        2                      ⎥
#                       ⎞                       ⎥
#                       ⎟                       ⎥
#  - 1.27748967997634e-8⎟                       ⎥
#                       ⎠                       ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
# ──────────────────────── - 8.17849743864196e-6⎥
#                        2                      ⎥
#                       ⎞                       ⎥
#                       ⎟                       ⎥
#  - 1.27748967997634e-8⎟                       ⎥
#                       ⎠                       ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
# ──────────────────────────────────            ⎥
#                                  2            ⎥
#                                 ⎞             ⎥
#          2                      ⎟             ⎥
# 8121 - D)  - 1.27748967997634e-8⎟             ⎥
#                                 ⎠             ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
# ──────────────────────────────────            ⎥
#                                  2            ⎥
#                                 ⎞             ⎥
#          2                      ⎟             ⎥
# 8121 - D)  - 1.27748967997634e-8⎟             ⎥
#                                 ⎠             ⎦

# %% [markdown]
# dissipative flow in terms of new dynamical varaibles:
